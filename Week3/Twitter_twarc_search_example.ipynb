# %% [markdown]
# In this lab, we will use 'twarc' Python package to interact with Twitter API v2.
#
# We will use Search Tweets --> Recent search (endpoint)
#
# This API endpoint:
# - (By default) Retrieves 10 tweets in the recent 7 days
# - (By setting max_results to 100) Can retrieve up to 100 tweets per API request
#
# Ref: https://twarc-project.readthedocs.io/en/latest/api/client2/#twarc.client2.Twarc2.search_recent
#
# Ref: https://www.youtube.com/watch?v=guHH51GDDI0
#
# Ref: https://catriscode.com/2021/05/01/tweets-cleaning-with-python/

# %%
import plotly.graph_objects as go
from twarc import Twarc2

# %%
# Paste in your own bearer token below
client = Twarc2(
    bearer_token = 'AAAAAAAAAAAAAAAAAAAAAIgDXwEAAAAA%2B%2FNOy4TBsIJvUFHy71iUi3XZEKM%3DsCO2F4oRltYGL2flK4Q3refT6FDegcC9Q6dEhQyEML9jrxrVMi'
)

# %%
query = 'covid lang=en'

# %%
results = client.search_recent(
    query=query,
    max_results=100,
    tweet_fields="author_id,context_annotations"
)

# %%
for page in results:
    print("======================")
    print(page)
    data = page['data']
# Out:
# ======================
# {'data': [{'id': '1488513718048768002', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '&lt;blockquote class="twitter-tweet"&gt;&lt;p lang="en" dir="ltr"&gt;Gather together safely with the strongest possible COVID protection. Everyone 12+ and vaccinated can now get a booster.&lt;/p&gt;&amp;mdash; https://t.co/m242EWkkJf (@HHSGov) &lt;a href="https://t.co/LB9Ia5iL8h"&gt;January 25, 2022&lt;/a&gt;', 'author_id': '1399139397010870273', 'referenced_tweets': [{'type': 'quoted', 'id': '1486126080922554369'}], 'entities': {'mentions': [{'start': 235, 'end': 242, 'username': 'HHSGov', 'id': '44783853'}]}}, {'id': '1488508759307546632', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @annaengblom: Some 1.6 million jobs were lost in Myanmar in 2021, with the military takeover compounding the impact of COVID-19. At the…', 'author_id': '704940912661635072', 'referenced_tweets': [{'type': 'retweeted', 'id': '1488409540878114820'}], 'entities': {'mentions': [{'start': 3, 'end': 15, 'username': 'annaengblom', 'id': '33461916'}]}}, {'id': '1488438542732861440', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'Dr Dinah Parums. Publications on COVID-19. World Health Organisation (WHO) Publication Resource. 2021/2022. https://t.co/P4XLu4PIB5', 'author_id': '1944331154'}, {'id': '1488428664320671744', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'Urgent.. The Prime Minister issues decision banning citizens and foreigners from entering all public and private institutions, including major markets, without presenting the Covid vaccination card https://t.co/QR1TlYhl7H via @NewsNowUK', 'author_id': '367091934', 'entities': {'mentions': [{'start': 226, 'end': 236, 'username': 'NewsNowUK', 'id': '68672354'}]}}, {'id': '1488425042954366982', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'COVID-19 OUTBREAK: THE KURDISTAN REGION PERSPECTIVE https://t.co/Vq93dpMc5B \n#TwitterKurds #Kurdistan #COVID19', 'author_id': '122794248'}, {'id': '1488409540878114820', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'Some 1.6 million jobs were lost in Myanmar in 2021, with the military takeover compounding the impact of COVID-19. At the same time, working hours decreased 18 per cent, equivalent to the working time of 3.1 million full-time workers. https://t.co/87YPIyGsdH https://t.co/Nd8a4LoZpJ', 'author_id': '33461916', 'attachments': {'media_keys': ['3_1488405978991276033']}}, {'id': '1488390415459962882', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '@RichardClip @ReubenR80027912 @guypbenson Long Covid is highly unproven and is mentioned to prolong these ridiculous NPIs.  You shouldn’t treat kids and adults differently when kids are at far lower risk:\n\nhttps://t.co/5KG9OXQDde\n\nC’mon man, give it up and let kids be normal.  Anything less is child abuse.', 'author_id': '1368503436870828036', 'in_reply_to_user_id': '1130242193514520576', 'referenced_tweets': [{'type': 'quoted', 'i ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487045453396992002', 'attachments': {'media_keys': ['3_1487045451174096898']}, 'entities': {'mentions': [{'start': 80, 'end': 95, 'username': 'ZMPublicHealth', 'id': '952834250797088769'}, {'start': 96, 'end': 106, 'username': 'mohzambia', 'id': '1200316338'}]}, 'text': 'Coronavirus - Zambia: COVID-19 Statistics Daily Status Update (28 January 2022) @ZMPublicHealth @mohzambia #Africa #Zambia #Health #Pandemic #Vaccination #Coronavirus #COVID19 #Vaccination #InfectiousDisease\nRead more: https://t.co/YR3WWq3g7Y https://t.co/N2RPNKyCLR', 'author_id': '255925055'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487034513704165376', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486975301296918528'}], 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'ILOAsiaPacific', 'id': '704940912661635072'}]}, 'text': 'RT @ILOAsiaPacific: Military takeover hammers #Myanmar labour market already weakened by impact of COVID-19. \n\n➡️1.6 million jobs lost in 2…', 'author_id': '1429925410066731048'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487033097958875136', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486975301296918528'}], 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'ILOAsiaPacific', 'id': '704940912661635072'}]}, 'text': 'RT @ILOAsiaPacific: Military takeover hammers #Myanmar labour market already weakened by impact of COVID-19. \n\n➡️1.6 million jobs lost in 2…', 'author_id': '833390968611151872'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487022834668900352', 'text': 'Nice to see 4 of my papers get a place in the WHO Literature Database on COVID 19: https://t.co/1Co3tv5cf0', 'author_id': '14144474'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487011483108229125', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486778297325273092'}], 'entities': {'mentions': [{'start': 3, 'end': 16, 'username': 'VPrasadMDMPH', 'id': '1194962714'}]}, 'text': 'RT @VPrasadMDMPH: Long COVID in kids is also not salient.  \nFirst of all, it has been massively exaggerated \n\nhttps://t.co/3BeiIMCr1i', 'author_id': '17934966'}, {'context_annotations': [{'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974597302226944', 'name': 'Transportation'}}, {'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487009532496822273', 'entities': {'mentions': [{'start': 66, 'end': 82, 'username': 'MarocDiplomatie', 'id': '2535581429'}]}, 'text': "COVID 19: Reopening of Morocco's airspace from Feb. 7 (statement) @MarocDiplomatie #Morocco #Africa #COVID19 #Coronavirus #Airlines #Aviation\nRead more: https://t.co/8IehlY293J", 'author_id': '255925055'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'id': '1487008025982681092', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'st ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486473115551084550', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '1239529420521684999'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486471086783045632', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '1259452727018565632'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486471035490902017', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '1136325846678065152'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486470574729801728', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '36041800'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486467739657068549', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '60678618'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486467593112371200', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '575763585'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486467379857137676', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms h ...
# ======================
# {'data': [{'author_id': '390767688', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486420846281474058', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '198233962', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486417380431609862', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '930176165054238720', 'text': 'How #SocialAndSolidarityEconomy initiatives contribute to achieving the #SDGs in the post-Covid context » (Ripess, 2021) | 👉🏽 Download it: https://t.co/lYnImv8UlT | #SSEforSDGs #SocialAndSolidarityEconomy #SocialEconomy', 'id': '1486417376438538240', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '255925055', 'text': 'Coronavirus - Malawi: COVID-19 Daily Info Update (26 January 2022) @health_malawi #Africa #Malawi #Health #Coronavirus #COVID19 #Pandemic #Vaccination #Update\nRead more: https://t.co/XnINMYWXXm https://t.co/19NTEozQyi', 'entities': {'mentions': [{'start': 67, 'end': 81, 'username': 'health_malawi', 'id': '1249718202877251590'}]}, 'id': '1486414139580891144', 'attachments': {'media_keys': ['3_1486414136909180937']}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '510905039', 'text': 'RT @oshawacity: COVID-19 Update: City recreation facilities to reopen January 31 for limited use - https://t.co/Ppj7MGehWP https://t.co/SBm…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486411294232166413'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'oshawacity', 'id': '87971828'}]}, 'id': '1486412388538757127', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '87971828', 'text': 'COVID-19 Update: City recreation facilities to reopen January 31 for limited use - https://t.co/Ppj7MGehWP https://t.co/SBmiEIonlZ', 'id': '1486411294232166413', 'attachments': {'media_keys': ['3_1486411292474814474']}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '2937344531', 'text': 'COVID-19 Update: City recreation facilities to reopen January 31 for limited use - https://t.co/QnDGPuCE3Z https://t.co/b7zZv7XqJj', 'id': '1486411290843271173', 'attachments': {'media_keys': ['3_1486411288792252420']}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '2617440133', 'text': 'COVID-19 Update: City recreation facilities to reopen January 31 for limited use - https://t.co/fkgn1ptA5h https://t.co/RipALRZozG', 'id': '1486411285323522048', 'attachm ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486344358161002504', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1063128503930023936', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486344241618038791', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '992197430048382981', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486344160793792515', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '117884205', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486344148814811138', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '537805821', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486343806865842178', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '144877857', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486343791124652040', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '2469801056', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…'}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486343722430312450', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '17654768', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in  ...
# ======================
# {'data': [{'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '172845798', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486286662502162435', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1463303052933226498', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486286593925304330', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1263770349671460864', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486286520923435011', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '2517663809', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486286431198887939', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '871122501757173760', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486286250134941708', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '142750417', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486285816380993538', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'author_id': '1258712054', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'id': '1486284333371568133', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories l ...
# ======================
# {'data': [{'id': '1486255103145304064', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '1106209087', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486255097185243136', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '19697582', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486254985155391495', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '2893619109', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486254875767971842', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '1015196564690743296', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486254858034458626', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '2597761064', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486254719685308416', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '424203744', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}}, {'id': '1486254623795130368', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'author_id': '832936404', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3 ...

# %%
len(data)
# Out:
# 44

# %%
# Convert JSON into Pandas data frame

import pandas as pd

df = pd.json_normalize(data)

df
# Out:
#                      id                                context_annotations  \
# 0   1486255103145304064  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1   1486255097185243136  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 2   1486254985155391495  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 3   1486254875767971842  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 4   1486254858034458626  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 5   1486254719685308416  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 6   1486254623795130368  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 7   1486254612118179841  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 8   1486254601561157639  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 9   1486254568354856961  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 10  1486254474092216326  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
# 33  RT @cint: https://t.co/c1SEviKkAw\n#Dutch #cov...            628312859
# 34  https://t.co/c1SEviKkAw\n#Dutch #covid19 Janua...             17229748
# 35  Rock Icon Neil Young Accuses Spotify of Spread...  1450393476722536449
# 36  Growing Number of Highly Vaccinated Cruise Shi...  1450393476722536449
# 37  @elvisonski @rpoconnor @WalmartCanada oooops\n...           2303422958
# 38  Australian Travel Industry Launching Protests ...  1450393476722536449
# 39  Large, Peer-Reviewed Research Study Proves Ive...  1450393476722536449
# 40  MOPH reported 2,124 new confirmed cases of COV...            298689306
# 41  RT @Right2CityGP: 📗 How SSE initiatives contri...            189546355
# 42  RT @CODESRIA: 📣Call for Papers for Special Iss...            167835170
# 43  RT @Right2CityGP: 📗 How SSE initiatives contri...            189364634
#
#                                     referenced_tweets  \
# 0   [{'type': 'retweeted', 'id': '1486253804270010...
# 1   [{'type': 'retweeted', 'id': '1486253804270010...
# 2   [{'type': 'retweeted', 'id': '1486253804270010...
# 3   [{'type': 'retweeted', 'id': '1486253804270010...
# 4   [{'type': 'retweeted', 'id': '1486253804270010...
# 5   [{'type': 'retweeted', 'id': '1486253804270010...
# 6   [{'type': 'retweeted', 'id': '1486253804270010...
# 7   [{'type': 'retweeted', 'id': '1486253804270010...
# 8   [{'type': 'retweeted', 'id': '1486253804270010...
# 9   [{'type': 'retweeted', 'id': '1486253804270010...
# 10  [{'type': 'retweeted', 'id': '1486253804270010...
# 11  [{'type': 'retweeted', 'id': '1486253804270010...
# 12  [{'type': 'retweeted', 'id': '1486253804270010...
# 13  [{'type': 'retweeted', 'id': '1486253804270010...
# 14  [{'type': 'retweeted', 'id': '1486253804270010...
# 15  [{'type': 'retweeted', 'id': '1486253804270010...
# 16  [{'type': 'retweeted', 'id': '1486253804270010...
# 17  [{'type': 'retweeted', 'id': '1486253804270010...
# 18  [{'type': 'retweeted', 'id': '1486253804270010...
# 19  [{'type': 'quoted', 'id': '1486114241170059264'}]
# 20  [{'type': 'replied_to', 'id': '148605455387951...
# 21  [{'type': 'replied_to', 'id': '148586847781884...
# 22  [{'type': 'retweeted', 'id': '1485890797740478...
# 23  [{'type': 'retweeted', 'id': '1486087453337436...
# 24                                                NaN
# 25                                                NaN
# 26  [{'type': 'quoted', 'id': '1473593864527171590...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  [{'type': 'retweeted', 'id': '1486056951297499...
# 31                                                NaN
# 32                                                NaN
# 33  [{'type': 'retweeted', 'id': '1486056951297499...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  [{'type': 'quoted', 'id': '1444339070579130377...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  [{'type': 'retweeted', 'id': '1485890797740478...
# 42  [{'type': 'retweeted', 'id': '1479063547204280...
# 43  [{'type': 'retweeted', 'id': '1485890797740478...
#
#                                     entities.mentions  \
# 0   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 1   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 2   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 3   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 4   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 5   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 6   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 7   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 8   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 9   [{'start': 3, 'end': 14, 'username': 'chrischi...
# 10  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 11  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 12  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 13  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 14  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 15  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 16  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 17  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 18  [{'start': 3, 'end': 14, 'username': 'chrischi...
# 19                                                NaN
# 20  [{'start': 0, 'end': 9, 'username': 'jebouman'...
# 21  [{'start': 0, 'end': 12, 'username': 'BartMesu...
# 22  [{'start': 3, 'end': 16, 'username': 'Right2Ci...
# 23  [{'start': 3, 'end': 11, 'username': 'untfsse'...
# 24                                                NaN
# 25                                                NaN
# 26  [{'start': 0, 'end': 14, 'username': 'agnostos...
# 27                                                NaN
# 28  [{'start': 158, 'end': 169, 'username': 'RIPES...
# 29                                                NaN
# 30  [{'start': 3, 'end': 8, 'username': 'cint', 'i...
# 31                                                NaN
# 32                                                NaN
# 33  [{'start': 3, 'end': 8, 'username': 'cint', 'i...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  [{'start': 0, 'end': 11, 'username': 'elvisons...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  [{'start': 3, 'end': 16, 'username': 'Right2Ci...
# 42  [{'start': 3, 'end': 12, 'username': 'CODESRIA...
# 43  [{'start': 3, 'end': 16, 'username': 'Right2Ci...
#
#      attachments.media_keys  in_reply_to_user_id
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
# 5                       NaN                  NaN
# 6                       NaN                  NaN
# 7                       NaN                  NaN
# 8                       NaN                  NaN
# 9                       NaN                  NaN
# 10                      NaN                  NaN
# 11                      NaN                  NaN
# 12                      NaN                  NaN
# 13                      NaN                  NaN
# 14                      NaN                  NaN
# 15                      NaN                  NaN
# 16                      NaN                  NaN
# 17                      NaN                  NaN
# 18                      NaN                  NaN
# 19  [3_1486253802101563393]                  NaN
# 20                      NaN            251576838
# 21                      NaN             19176919
# 22                      NaN                  NaN
# 23                      NaN                  NaN
# 24                      NaN                  NaN
# 25  [3_1486143661721141248]                  NaN
# 26                      NaN  1266168336519270400
# 27  [3_1485866642991362054]                  NaN
# 28  [3_1486086717127942145]                  NaN
# 29  [3_1486082192447000578]                  NaN
# 30                      NaN                  NaN
# 31                      NaN                  NaN
# 32                      NaN                  NaN
# 33                      NaN                  NaN
# 34  [3_1486056919995494405]                  NaN
# 35                      NaN                  NaN
# 36                      NaN                  NaN
# 37                      NaN             23789149
# 38                      NaN                  NaN
# 39                      NaN                  NaN
# 40  [3_1486026255845707777]                  NaN
# 41                      NaN                  NaN
# 42                      NaN                  NaN
# 43                      NaN                  NaN

# %%
# Let's retrieve just the text from each tweet
# Store each tweet text as a List item

tweet_text_list = df['text'].tolist()

tweet_text_list
# Out:
# ['RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…',
#  'French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and how Omicron is surging through this age group. \n\nWhere are our medical societies?\n\nhttps://t.co/PpegTj0Lso https://t.co/bDB2UKsjcL https://t.co/FdDt7wH2JK',
#  '@jebouman @rivm @MinVWS @MinPres volgens realistischer onderzoeken tot 25%. Maar de definitie hangt af wat lang is. Het is overigens post-covid als je de juiste term wil gebruiken. \n\nMaar een jaar.. ik (ervaring) vind het erg lang en het is nog niet voorbij.',
#  '@BartMesuere Hou toch op met die cijfers. Mensen worden MET covid opgenomen, niet DOOR. STOP MET TESTEN, BEHANDEL DE ZIEKEN, VACCINEER DE OUDEREN EN RISICOPATIËNTEN, STOP DE MAATREGELEN,...en we leefden nog lang en gelukkig...',
#  'RT @Right2CityGP: 📗 How SSE initiatives contribute to achieving the SDGs in the post-Covid context \n\n🙌🏼Diverse and inclusive economies are…',
#  'RT @CODESRIA: 📣Call for Papers for Special Issue\nOn COVID-19 and Its Effects and Implications to African Economies.\nLike and share!\n👉https:…',
#  'RT @Right2CityGP: 📗 How SSE initiatives contribute to achieving the SDGs in the post-Covid context \n\n🙌🏼Diverse and inclusive economies are…']

# %%
'''
1) Lowercasing all the letters

This step is important to make sure that all your letters are in uniform.

temp = tweet.lower()
temp
'''

# %%
'''
2) Removing hashtags and mentions

Hashtags and mentions are common in tweets.
There are cases where you want to remove them so you only get the 
clean content of a tweet without all these elements.

You can remove these hashtags and mentions using regex.

import re

temp = re.sub("@[A-Za-z0-9_]+","", temp)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp
'''

# %%
'''
3) Removing links

Links are usually not necessary for text processing, so it’s
better to remove them from your text.

temp = re.sub(r"http\S+", "", temp)
temp = re.sub(r"www.\S+", "", temp)
temp
'''

# %%
'''
4) Removing punctuations

Depending on your needs, you may not need punctuations such as
period, comma, exclamation mark, question mark, etc.

temp = re.sub('[()!?]', ' ', temp)
temp = re.sub('\[.*?\]',' ', temp)
temp
'''

# %%
'''
5) Filtering non-alphanumeric characters

The previous step may have removed the punctuations, including all the
non-alphanumeric characters, but just to be sure, we can remove all letters
except the alphabets (a-z) and numbers (0-9). The sign ^ below means except.

temp = re.sub("[^a-z0-9]"," ", temp)
temp
'''

# %%
'''
6) Tokenization

In tokenization, you basically tokenize your text into tokens.

And what is a token? In this case, you split your text into smaller components,
for example a paragraph into a list of sentences, or a sentence into a list of words.

Library such as nltk provides functions such as word_tokenize() or sent_tokenize()
to help you with this.

However, if you just want a simple tokenizing step where you split your text 
into words into a list, then you can do it as simple as the following code.

The result will give you a list of words from your text.

temp = temp.split()
temp
'''

# %%
'''
7) Stop words removal

Stop words are words that are considered unimportant to the meaning of a text.
These words may seem important to us, humans, but to machine these words may be
considered nuisance to the processing steps.

It’s also important to keep in mind that stop words are largely language-dependent.
In English, you have stop words such as for, to, and, or, in, out, etc.

Here I first defined a list of stop words in English.
Then, I match each token with each stop word.

If a token isn’t found in the list of stop words, the token gets saved,
otherwise it’s not saved. In the end, you join all the words into one text again.


stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
temp = [w for w in temp if not w in stopwords]
temp = " ".join(word for word in temp)
'''

# %%
'''
Text Preprocessing: From Start to Finish

I hope you understand the steps I have explained above.
Now we can combine all those lines of code into one function that we can
call and pass an argument to.

The function then returns a clean text that is ready for you to work with.

Keep in mind that the order of steps here are not absolute.
You can arrange them around depending on your text and your needs.
The code below is what I found to be the most effective on the data I
usually work with, but in case you find another pattern of data,
you can always work them out differently.
'''
import numpy as np
import re

stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
tweets = ["Get ready for #NatGeoEarthDay! Join us on 4/21 for an evening of music and celebration, exploration and inspiration https://on.natgeo.com/3t0wzQy.",
"Coral in the shallows of Aitutaki Lagoon, Cook Islands, Polynesia https://on.natgeo.com/3gkgq4Z",
"Don't miss our @reddit AMA with author and climber Mark Synnott who will be answering your questions about his historic journey to the North Face of Everest TODAY at 12:00pm ET! Start submitting your questions here: https://on.natgeo.com/3ddSkHk @DuttonBooks"]
 
results = [clean_tweet(tw) for tw in tweets]
results
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12416/1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['get ready join us 4 21 evening music celebration exploration inspiration',
#  'coral shallows aitutaki lagoon cook islands polynesia',
#  'dont miss our ama with author climber mark synnott who will be answering your questions about his historic journey north face everest today at 12 00pm et start submitting your questions here']

# %%
# Let's go and apply this to our own tweets
my_results = [clean_tweet(tw) for tw in tweet_text_list]
my_results
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12416/1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'rt french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine',
#  'french academy medicine urges vaccination 5 11s strongest terms highlighting safety efficacy vaccine how omicron is surging through this age group where are our medical societies',
#  'volgens realistischer onderzoeken tot 25 maar de definitie hangt af wat lang is het is overigens post covid als je de juiste term wil gebruiken maar een jaar ik ervaring vind het erg lang en het is nog niet voorbij',
#  'hou toch op met die cijfers mensen worden met covid opgenomen niet door stop met testen behandel de zieken vaccineer de ouderen en risicopati nten stop de maatregelen en we leefden nog lang en gelukkig',
#  'rt how sse initiatives contribute achieving sdgs post covid context diverse inclusive economies are',
#  'rt publication how sse initiatives contribute achieving post covid context ripess 2021 downloa',
#  'over 1 million people america are now covid 19 positive',
#  'covid is live streaming mico',
#  'looked him up would suggest that you research memes quotes before you use them misrepresent stance holocaust survivors as you defend comparison covid mitigation measures systematic slaughter jewish people',
#  'our highgate park covid 19 vaccination clinic is open today 10am walk s available or book your appointment at vaccinations ages 12 years over only see you there',
#  'publication how sse initiatives contribute achieving post covid context ripess 2021 download it',
#  'ministry health kuwait reports 5 742 people tested positive coronavirus covid 19 one death past 24 hours',
#  'rt january 25 positive 54160 4 008 459 nice',
#  'court rules covid shutdown cinemas amp theaters after uproar',
#  'covid 19 lab mistakenly tells hundreds people they tested negative australia officials',
#  'rt january 25 positive 54160 4 008 459 nice',
#  'january 25 positive 54160 4 008 459 nice 12 00 am 20 79 335 8 21 227 click select',
#  'rock icon neil young accuses spotify spreading covid misinformation demands removal his music',
#  'growing number highly vaccinated cruise ships facing disruption over covid 19',
#  'oooops',
#  'australian travel industry launching protests against spider web covid 19 restrictions',
#  'large peer reviewed research study proves ivermectin works against covid 19',
#  'moph reported 2 124 new confirmed cases covid 19 among community 427 among travelers moph recorded 4 018 recoveries virus during past 24 hours bringing total number cases recovered 293 182 moph announced one new death was recorded',
#  'rt how sse initiatives contribute achieving sdgs post covid context diverse inclusive economies are',
#  'rt call papers special issue covid 19 its effects implications african economies like share',
#  'rt how sse initiatives contribute achieving sdgs post covid context diverse inclusive economies are']

# %%
# importing all necessary modules

# Note that wordcloud package also provides a stop word list
# We won't be using it here - but please do explore!!!
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
